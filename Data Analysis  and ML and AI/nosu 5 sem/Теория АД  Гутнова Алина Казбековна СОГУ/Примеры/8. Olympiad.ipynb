# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
PATH = '/content/drive/MyDrive/Colab Notebooks/ПМ-2022/АД/data/Муниципальный этап/'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(PATH + "Munic7-8_2024.csv")

# %%
df.head()
# Out:
#             id      tiem_send              task  id_user           lang  \
# 0  129118217.0  12/5/24 11:14         B. MaxSum  munic59  Python 3.12.3
# 1          NaN            NaN               NaN      NaN            NaN
# 2  129118214.0  12/5/24 11:14         B. MaxSum   munic4  C# (.NET 8.0)
# 3  129118160.0  12/5/24 11:14  E. Антоша и ITMO  munic46  Python 3.12.3
# 4          NaN            NaN               NaN      NaN            NaN
#
#   verdict  score duration_time memory_solution
# 0      WA   10.0        1.10 с        179.6 Мб
# 1       6    NaN           NaN             NaN
# 2      CE    NaN          0 мс          0 байт
# 3      PE    0.0         46 мс          4.5 Мб
# 4       1    NaN           NaN             NaN

# %%
df.shape
# Out:
# (1432, 9)

# %%
df = df.dropna(subset=['id'])

# %%
df.shape
# Out:
# (818, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 818 entries, 0 to 1430
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               818 non-null    float64
#  1   tiem_send        818 non-null    object
#  2   task             818 non-null    object
#  3   id_user          818 non-null    object
#  4   lang             818 non-null    object
#  5   verdict          818 non-null    object
#  6   score            677 non-null    float64
#  7   duration_time    818 non-null    object
#  8   memory_solution  818 non-null    object
# dtypes: float64(2), object(7)
# memory usage: 63.9+ KB

# %%
df.head()
# Out:
#             id      tiem_send              task   id_user           lang  \
# 0  129118217.0  12/5/24 11:14         B. MaxSum   munic59  Python 3.12.3
# 2  129118214.0  12/5/24 11:14         B. MaxSum    munic4  C# (.NET 8.0)
# 3  129118160.0  12/5/24 11:14  E. Антоша и ITMO   munic46  Python 3.12.3
# 5  129118151.0  12/5/24 11:14      A. Туда сюда  munic109  Python 3.12.3
# 6  129118145.0  12/5/24 11:14      A. Туда сюда   munic23  Python 3.12.3
#
#   verdict  score duration_time memory_solution
# 0      WA   10.0        1.10 с        179.6 Мб
# 2      CE    NaN          0 мс          0 байт
# 3      PE    0.0         46 мс          4.5 Мб
# 5      CE    NaN          0 мс          0 байт
# 6      WA    0.0         46 мс          4.6 Мб

# %%
df.task.value_counts()
# Out:
# task
# A. Туда сюда              286
# B. MaxSum                 193
# C. Алина и числа          158
# D. Вершина и интенсивы    129
# E. Антоша и ITMO           52
# Name: count, dtype: int64

# %%
df.lang.value_counts()
# Out:
# lang
# Python 3.12.3            453
# C++20 (GCC 14.1)         274
# C# (.NET 8.0)             83
# PascalABC.NET 3.9.0        6
# Java 21 (Temurin JDK)      2
# Name: count, dtype: int64

# %%
df.userID.nunique()
# Out:
# 79

# %%
df.userID.value_counts()
# Out:
# userID
# munic85     40
# munic59     32
# munic102    24
# munic84     23
# munic74     23
#             ..
# munic6       1
# munic49      1
# munic7       1
# munic8       1
# munic101     1
# Name: count, Length: 79, dtype: int64

# %%
user_ignor = df[df['verdict']=="IG"]['userID'].value_counts()
user_ignor
# Out:
# userID
# munic58     14
# munic84     13
# munic109     3
# munic1       2
# munic23      1
# munic42      1
# munic38      1
# munic46      1
# Name: count, dtype: int64

# %%
user_ignor_name = user_ignor.index
user_ignor_name
# Out:
# Index(['munic58', 'munic84', 'munic109', 'munic1', 'munic23', 'munic42',
#        'munic38', 'munic46'],
#       dtype='object', name='userID')

# %%
df[df['userID']=="munic84"]
# Out:
#                ID              time                    task   userID  \
# 150   129131429.0  05.12.2024 12:57               B. MaxSum  munic84
# 274   129128598.0  05.12.2024 12:32            A. “уда сюда  munic84
# 303   129128205.0  05.12.2024 12:28            A. “уда сюда  munic84
# 347   129127474.0  05.12.2024 12:22            A. “уда сюда  munic84
# 409   129126521.0  05.12.2024 12:13            A. “уда сюда  munic84
# 983   129116958.0  05.12.2024 11:07        E. јнтоша и ITMO  munic84
# 1001  129116770.0  05.12.2024 11:06  D. ¬ершина и интенсивы  munic84
# 1013  129116607.0  05.12.2024 11:05  D. ¬ершина и интенсивы  munic84
# 1037  129116336.0  05.12.2024 11:04  D. ¬ершина и интенсивы  munic84
# 1048  129116171.0  05.12.2024 11:03  D. ¬ершина и интенсивы  munic84
# 1062  129115934.0  05.12.2024 11:02        E. јнтоша и ITMO  munic84
# 1091  129115700.0  05.12.2024 11:00        E. јнтоша и ITMO  munic84
# 1100  129115535.0  05.12.2024 10:59  D. ¬ершина и интенсивы  munic84
# ...

# %%
import numpy as np

df_pivot_table = df.pivot_table(index=['task'], columns=['lang'], values="ID", aggfunc=[np.count_nonzero])
df_pivot_table
# Out:
#                        count_nonzero                                         \
# lang                   C# (.NET 8.0) C++20 (GCC 14.1) Java 21 (Temurin JDK)
# task
# A. “уда сюда                    30.0             50.0                   NaN
# B. MaxSum                       22.0             83.0                   NaN
# C. јлина и числа                10.0             87.0                   1.0
# D. ¬ершина и интенсивы          14.0             42.0                   NaN
# E. јнтоша и ITMO                 7.0             12.0                   1.0
#
#
# lang                   PascalABC.NET 3.9.0 Python 3.12.3
# task
# A. “уда сюда                           5.0         201.0
# B. MaxSum                              NaN          88.0
# C. јлина и числа                       1.0          59.0
# D. ¬ершина и интенсивы                 NaN          73.0
# E. јнтоша и ITMO                       NaN          32.0

# %%
df_pivot_table_ignor = df[df['verdict']=="IG"].pivot_table(index=['task'], columns=['lang'], values="ID", aggfunc=[np.count_nonzero])
df_pivot_table_ignor
# Out:
#                           count_nonzero
# lang                   C++20 (GCC 14.1) Python 3.12.3
# task
# A. “уда сюда                        NaN           1.0
# B. MaxSum                           NaN           5.0
# C. јлина и числа                    4.0           7.0
# D. ¬ершина и интенсивы              NaN          11.0
# E. јнтоша и ITMO                    NaN           8.0

# %%
df_ignor = df[df.userID.isin(user_ignor_name)]
df_ignor
# Out:
#                ID              time              task    userID  \
# 3     129118160.0  05.12.2024 11:14  E. јнтоша и ITMO   munic46
# 5     129118151.0  05.12.2024 11:14      A. “уда сюда  munic109
# 6     129118145.0  05.12.2024 11:14      A. “уда сюда   munic23
# 19    129118018.0  05.12.2024 11:13         B. MaxSum   munic42
# 21    129117930.0  05.12.2024 11:12  C. јлина и числа   munic58
# ...           ...               ...               ...       ...
# 1389  129111640.0  05.12.2024 10:35      A. “уда сюда   munic84
# 1401  129111419.0  05.12.2024 10:34      A. “уда сюда    munic1
# 1406  129111345.0  05.12.2024 10:33      A. “уда сюда   munic84
# 1422  129111142.0  05.12.2024 10:32      A. “уда сюда   munic84
# 1425  129111121.0  05.12.2024 10:32      A. “уда сюда   munic84
#
#                   lang verdict  score time_solution memory_solution
# 3        Python 3.12.3      PE    0.0         46 мс          4.5 ћб
# ...

# %%
df_ignor.shape
# Out:
# (107, 9)

# %%
df_ignor.pivot_table(index=['task'], columns=['verdict'], values="ID", aggfunc=[np.count_nonzero])
# Out:
#                        count_nonzero
# verdict                           CE    IG   ML   OK   PE   RE   TL    WA
# task
# A. “уда сюда                     8.0   1.0  NaN  2.0  3.0  3.0  4.0  13.0
# B. MaxSum                        9.0   5.0  NaN  NaN  1.0  NaN  NaN  10.0
# C. јлина и числа                 1.0  11.0  NaN  NaN  NaN  NaN  NaN   3.0
# D. ¬ершина и интенсивы           1.0  11.0  NaN  NaN  NaN  1.0  NaN   5.0
# E. јнтоша и ITMO                 NaN   8.0  1.0  NaN  4.0  2.0  NaN   NaN

# %%
df_true = df[~df.userID.isin(user_ignor_name)]
df_true.shape
# Out:
# (711, 9)

# %%
df_true.pivot_table(index=['task'], columns=['verdict'], values="ID", aggfunc=[np.count_nonzero])
# Out:
#                        count_nonzero
# verdict                           CE   ML    OK    PE    RE    TL    WA
# task
# A. “уда сюда                    47.0  NaN  31.0   8.0  58.0  29.0  79.0
# B. MaxSum                       23.0  NaN  17.0  15.0  14.0   5.0  94.0
# C. јлина и числа                25.0  1.0   4.0   2.0  14.0  30.0  67.0
# D. ¬ершина и интенсивы          16.0  NaN   2.0   8.0   7.0  19.0  59.0
# E. јнтоша и ITMO                11.0  2.0   2.0   3.0   1.0   1.0  17.0

# %% [markdown]
# Средняя частота отправки решения

# %% [markdown]
# удалим дату, оставим только время

# %%
df['time'] = df['time'].str.split()
df.sample(10)
# Out:
#                ID  time                    task   userID              lang  \
# 621   129122592.0   NaN               B. MaxSum  munic93     C# (.NET 8.0)
# 811   129119272.0   NaN            A. “уда сюда   munic9     Python 3.12.3
# 482   129124942.0   NaN        C. јлина и числа  munic65  C++20 (GCC 14.1)
# 955   129117462.0   NaN               B. MaxSum  munic59     Python 3.12.3
# 384   129126889.0   NaN        C. јлина и числа  munic79     Python 3.12.3
# 250   129129160.0   NaN               B. MaxSum  munic55  C++20 (GCC 14.1)
# 1323  129112691.0   NaN            A. “уда сюда  munic14     Python 3.12.3
# 48    129117682.0   NaN            A. “уда сюда   munic2     Python 3.12.3
# 1001  129116770.0   NaN  D. ¬ершина и интенсивы  munic84     Python 3.12.3
# 331   129127754.0   NaN  D. ¬ершина и интенсивы  munic85     Python 3.12.3
#
#      verdict  score time_solution memory_solution
# 621       CE    NaN          0 мс          0 байт
# ...
